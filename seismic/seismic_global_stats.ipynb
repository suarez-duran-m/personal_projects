# %% [markdown]
# # Colombia seimic global stats
# (1st June, 1993 to 31st May, 2023)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from ydata_profiling import ProfileReport

# %% [markdown]
# ## Data Collection:
#
# The data was downloaded form Servicio geológico colombiano, http://bdrsnc.sgc.gov.co/paginas1/catalogo/index.php and splited in 14 files: "reporte???.xlsx"

# %% [markdown]
# ## Data Wrangling
#
# According with the Servicio geológico colombiano, the data was collected and made public in two campaigns:
#
# * Firsh batch: from 1st of June, 1993 to 28th of Febraury, 2018. Registered by SEISAN software.
# * Firsh batch: from 1st of March, 2018 to 31st of May, 2023. Registered by SeisComp33 software.
#
# See more details in the previous link.
#
# In line with the above, the data is coming with different fields between them.

# %%
# List of file names
files_1st_batch = ['data/reporte9.xlsx', 'data/reporte1244.xlsx', 'data/reporte160.xlsx', 'data/reporte1805.xlsx', 'data/reporte1922.xlsx', 'data/reporte239.xlsx', 'data/reporte362.xlsx', 'data/reporte665.xlsx']
files_2nd_batch = ['data/reporte1091.xlsx', 'data/reporte1629.xlsx', 'data/reporte1796.xlsx', 'data/reporte871.xlsx', 'data/reporte974.xlsx', 'data/reporte97.xlsx']

# Empty list to store DataFrames
dfs_1st_batch = []
dfs_2nd_batch = []

# Read each file and append DataFrame to the list
for file_name in files_1st_batch:
    tmp_df = pd.read_excel(file_name)
    dfs_1st_batch.append(tmp_df)
    
for file_name in files_2nd_batch:
    tmp_df = pd.read_excel(file_name)
    dfs_2nd_batch.append(tmp_df)

# Concatenate the DataFrames
seismic_1st_batchFull = pd.concat(dfs_1st_batch)
seismic_1st_batchFull = seismic_1st_batchFull.reset_index(drop=True)
seismic_2nd_batchFull = pd.concat(dfs_2nd_batch)
seismic_2nd_batchFull = seismic_2nd_batchFull.reset_index(drop=True)

# %%
print("Describe for first batch")
seismic_1st_batchFull.describe()
# Out:
# Describe for first batch
#        LATITUD (grados)  LONGITUD (grados)  PROFUNDIDAD (Km)    MAGNITUD Ml  \
# count     173275.000000      173275.000000     173275.000000  173275.000000
# mean           6.230927         -73.988323         99.446401       2.117948
# std            1.584885           1.513679         60.826182       0.704426
# min           -3.483000         -83.400000          0.000000       0.100000
# 25%            5.848000         -74.508000         24.100000       1.600000
# 50%            6.784000         -73.174000        138.000000       2.000000
# 75%            6.831000         -73.095000        146.900000       2.500000
# max           14.907000         -70.168000        700.000000       6.800000
#
#        MAGNITUD Mw        # FASES      RMS (Seg)   GAP (grados)  \
# count  4544.000000  173275.000000  173086.000000  173086.000000
# mean      3.438688       7.443463       0.449777     177.535231
# std       0.530064       4.643028       0.236118      61.328644
# min       0.100000       0.000000       0.000000       0.000000
# 25%       3.100000       5.000000       0.300000     135.000000
# 50%       3.400000       6.000000       0.400000     174.000000
# 75%       3.700000       8.000000       0.500000     213.000000
# max       7.100000      96.000000       9.400000     360.000000
#
#        ERROR LATITUD (Km)  ERROR LONGITUD (Km)  ERROR PROFUNDIDAD (Km)
# count       173086.000000        173086.000000           173086.000000
# mean             6.625142             9.251236               11.397149
# std              7.936443             9.856246               12.275819
# min              0.000000             0.000000                0.000000
# 25%              3.300000             4.000000                5.900000
# 50%              4.600000             6.200000                7.900000
# 75%              6.900000            10.900000               11.600000
# max             99.900000            99.900000               99.900000

# %%
print("Columns name\n")
for i in seismic_1st_batchFull.columns.to_list():
    print(i)
# Out:
# Columns name
#
# FECHA
# HORA_UTC
# LATITUD (grados)
# LONGITUD (grados)
# PROFUNDIDAD (Km)
# MAGNITUD Ml
# MAGNITUD Mw
# DEPARTAMENTO
# MUNICIPIO
# # FASES
# RMS (Seg)
# GAP (grados)
# ERROR LATITUD (Km)
# ERROR LONGITUD (Km)
# ERROR PROFUNDIDAD (Km)
# ESTADO

# %%
print("Describe for second batch")
seismic_2nd_batchFull.describe()
# Out:
# Describe for second batch
#          LATITUD (°)   LONGITUD (°)     PROF. (Km)       MAGNITUD  \
# count  126459.000000  126459.000000  126459.000000  126459.000000
# mean        6.134687     -74.232196      85.593697       1.729508
# std         1.911706       1.548449      58.579244       0.528979
# min        -3.587000     -89.985000      -4.940000       0.100000
# 25%         5.176000     -75.221000      19.965000       1.400000
# 50%         6.761000     -73.507000     110.490000       1.700000
# 75%         6.831000     -73.163000     140.900000       2.000000
# max        14.314000     -69.022000     461.870000       6.600000
#
#                FASES      RMS (Seg)        GAP (°)  ERROR LATITUD (Km)  \
# count  126459.000000  126459.000000  126459.000000       126459.000000
# mean       17.493646       0.566562     135.683542            2.759717
# std        12.842566       0.313320      53.897128            1.966607
# min         3.000000       0.000000      18.000000            0.000000
# 25%         9.000000       0.300000     100.000000            1.273000
# 50%        13.000000       0.500000     131.000000            2.121000
# 75%        21.000000       0.800000     162.000000            3.722000
# max       123.000000       4.900000     353.000000           56.781000
#
#        ERROR LONGITUD (Km)  ERROR PROFUNDIDAD (Km)
# count        126459.000000           126459.000000
# mean              2.907980                4.410459
# std               2.181952                3.868208
# min               0.000000                0.000000
# 25%               1.273000                2.100000
# 50%               2.121000                3.500000
# 75%               4.037000                6.400000
# max              56.781000              641.500000

# %%
print("Columns name\n")
for i in seismic_2nd_batchFull.columns.to_list():
    print(i)
# Out:
# Columns name
#
# FECHA - HORA UTC
# LATITUD (°)
# LONGITUD (°)
# PROF. (Km)
# MAGNITUD
# TIPO MAGNITUD
# FASES
# RMS (Seg)
# GAP (°)
# ERROR LATITUD (Km)
# ERROR LONGITUD (Km)
# ERROR PROFUNDIDAD (Km)
# REGION
# ESTADO

# %%
# Chosen columns of interest and renaming
seismic_1st_batch = seismic_1st_batchFull[['FECHA', 'HORA_UTC', 'LATITUD (grados)', 'LONGITUD (grados)', 'PROFUNDIDAD (Km)', 'MAGNITUD Ml', 'MAGNITUD Mw', 'DEPARTAMENTO', 'MUNICIPIO', 'ERROR LATITUD (Km)', 'ERROR LONGITUD (Km)', 'ERROR PROFUNDIDAD (Km)', 'ESTADO']].copy()
seismic_1st_batch.rename(columns={"LATITUD (grados)": "LAT", "LONGITUD (grados)": "LONG", 'PROFUNDIDAD (Km)': "PROF.", "ERROR LATITUD (Km)": "ERR-LAT", "ERROR LONGITUD (Km)": "ERR-LONG", "ERROR PROFUNDIDAD (Km)": "ERR-PROF"}, inplace=True)

print("First batch", '\n')
for i in seismic_1st_batch.columns.to_list():
    print(i)

seismic_2nd_batch = seismic_2nd_batchFull[['FECHA - HORA UTC', 'LATITUD (°)', 'LONGITUD (°)', 'PROF. (Km)', 'MAGNITUD', 'TIPO MAGNITUD', 'ERROR LATITUD (Km)', 'ERROR LONGITUD (Km)', 'ERROR PROFUNDIDAD (Km)', 'REGION', 'ESTADO']].copy()
seismic_2nd_batch.rename(columns={"LATITUD (°)": "LAT", "LONGITUD (°)": "LONG", 'PROF. (Km)': "PROF.", "ERROR LATITUD (Km)": "ERR-LAT", "ERROR LONGITUD (Km)": "ERR-LONG", "ERROR PROFUNDIDAD (Km)": "ERR-PROF"}, inplace=True)

print("\nSecond batch", '\n')
for i in seismic_2nd_batch.columns.to_list():
    print(i)
# Out:
# First batch
#
# FECHA
# HORA_UTC
# LAT
# LONG
# PROF.
# MAGNITUD Ml
# MAGNITUD Mw
# DEPARTAMENTO
# MUNICIPIO
# ERR-LAT
# ERR-LONG
# ERR-PROF
# ESTADO
#
# Second batch
#
# FECHA - HORA UTC
# LAT
# LONG
# PROF.
# MAGNITUD
# TIPO MAGNITUD
# ERR-LAT
# ERR-LONG
# ERR-PROF
# REGION
# ESTADO

# %% [markdown]
# ## Standardizing

# %% [markdown]
# ### Checking for duplicate rows

# %%
seismic_1st_batch[seismic_1st_batch.duplicated(subset=seismic_1st_batch.columns, keep=False)]
# Out:
#              FECHA  HORA_UTC    LAT    LONG  PROF.  MAGNITUD Ml  MAGNITUD Mw  \
# 55267   2005-02-28  23:34:42  6.813 -73.027  150.2          2.4          NaN
# 55268   2005-02-28  23:34:42  6.813 -73.027  150.2          2.4          NaN
# 74701   2009-06-11  01:50:05  4.697 -76.317   76.5          1.4          NaN
# 74702   2009-06-11  01:50:05  4.697 -76.317   76.5          1.4          NaN
# 74703   2009-06-11  02:20:57  6.815 -73.163  149.0          3.9          NaN
# 74704   2009-06-11  02:20:57  6.815 -73.163  149.0          3.9          NaN
# 74705   2009-06-11  03:45:52  6.810 -73.111  148.9          2.3          NaN
# 74706   2009-06-11  03:45:52  6.810 -73.111  148.9          2.3          NaN
# 74707   2009-06-11  04:21:21  6.772 -72.976  156.6          1.6          NaN
# 74708   2009-06-11  04:21:21  6.772 -72.976  156.6          1.6          NaN
# 74709   2009-06-11  06:25:51  7.477 -74.113    8.4          1.6          NaN
# 74710   2009-06-11  06:25:51  7.477 -74.113    8.4          1.6          NaN
# 74711   2009-06-11  06:27:40  7.734 -73.024  142.1          1.3          NaN
# 74712   2009-06-11  06:27:40  7.734 -73.024  142.1          1.3          NaN
# 74713   2009-06-11  06:31:28  3.847 -75.718    4.0          1.9          NaN
# 74714   2009-06-11  06:31:28  3.847 -75.718    4.0          1.9          NaN
# 74715   2009-06-11  06:43:17  6.847 -73.173  128.6          1.9          NaN
# 74716   2009-06-11  06:43:17  6.847 -73.173  128.6          1.9          NaN
# 74717   2009-06-11  06:44:23  6.796 -73.165  146.0          1.8          NaN
# 74718   2009-06-11  06:44:23  6.796 -73.165  146.0          1.8          NaN
# 74719   2009-06-11  06:56:18  6.893 -72.148    0.0          2.7          NaN
# 74720   2009-06-11  06:56:18  6.893 -72.148    0.0          2.7          NaN
# 74722   2009-06-11  07:32:14  7.228 -74.379   13.3          1.5          NaN
# 74723   2009-06-11  07:32:14  7.228 -74.379   13.3          1.5          NaN
# 74724   2009-06-11  08:27:18  6.780 -73.123  152.8          1.7          NaN
# 74725   2009-06-11  08:27:18  6.780 -73.123  152.8          1.7          NaN
# 74727   2009-06-11  10:33:10  8.271 -74.946    0.0          1.9          NaN
# 74728   2009-06-11  10:33:10  8.271 -74.946    0.0          1.9          NaN
# 74729   2009-06-11  10:44:01  6.869 -73.149  153.1          2.6          NaN
# 74730   2009-06-11  10:44:01  6.869 -73.149  153.1          2.6          NaN
# 74731   2009-06-11  10:44:02  6.814 -73.127  139.8          2.8          NaN
# 74732   2009-06-11  10:44:02  6.844 -73.157  143.6          2.7          NaN
# 74733   2009-06-11  10:44:02  6.844 -73.157  143.6          2.7          NaN
# 74734   2009-06-11  10:44:02  6.814 -73.127  139.8          2.8          NaN
# 74735   2009-06-11  10:53:31  6.794 -73.106  146.8          2.4          NaN
# 74736   2009-06-11  10:53:31  6.794 -73.106  146.8          2.4          NaN
# 74737   2009-06-11  10:53:31  6.827 -73.158  148.0          2.7          NaN
# 74738   2009-06-11  10:53:31  6.827 -73.158  148.0          2.7          NaN
# 74739   2009-06-11  16:45:57  4.248 -75.972    4.5          2.4          NaN
# 74740   2009-06-11  16:45:57  4.248 -75.972    4.5          2.4          NaN
# 74741   2009-06-11  19:00:18  4.464 -73.659    1.5          2.9          NaN
# 74742   2009-06-11  19:00:18  4.464 -73.659    1.5          2.9          NaN
# 74743   2009-06-11  22:47:18  6.495 -75.894   76.0          1.8          NaN
# 74744   2009-06-11  22:47:18  6.495 -75.894   76.0          1.8          NaN
# 74745   2009-06-11  23:56:58  5.064 -76.781   32.0          2.9          NaN
# 74746   2009-06-11  23:56:58  5.064 -76.781   32.0          2.9          NaN
# 148985  2012-02-08  10:33:32  4.228 -76.814   17.8          1.6          NaN
# 148986  2012-02-08  10:33:32  4.228 -76.814   17.8          1.6          NaN
# 150180  2012-03-07  09:18:55  4.028 -75.925  167.8          2.6          NaN
# 150181  2012-03-07  09:18:55  4.028 -75.925  167.8          2.6          NaN
# 150781  2012-03-25  08:11:51  6.774 -73.133  144.8          2.5          NaN
# 150782  2012-03-25  08:11:51  6.774 -73.133  144.8          2.5          NaN
# 168884  2013-08-26  00:06:44  7.708 -75.024   18.2          1.8          NaN
# 168885  2013-08-26  00:06:44  7.708 -75.024   18.2          1.8          NaN
#
#               DEPARTAMENTO           MUNICIPIO  ERR-LAT  ERR-LONG  ERR-PROF  \
# 55267            SANTANDER              CEPITA      5.6      10.9       7.9
# 55268            SANTANDER              CEPITA      5.6      10.9       7.9
# 74701      VALLE DEL CAUCA            EL_CAIRO      6.2      14.7      21.7
# 74702      VALLE DEL CAUCA            EL_CAIRO      6.2      14.7      21.7
# 74703            SANTANDER          LOS_SANTOS      3.6       6.8       9.3
# 74704            SANTANDER          LOS_SANTOS      3.6       6.8       9.3
# 74705            SANTANDER          LOS_SANTOS      4.3      10.9      11.7
# 74706            SANTANDER          LOS_SANTOS      4.3      10.9      11.7
# 74707            SANTANDER              CEPITA      7.9       9.3       9.2
# 74708            SANTANDER              CEPITA      7.9       9.3       9.2
# 74709              BOLIVAR           SAN_PABLO      4.9       8.2       6.2
# 74710              BOLIVAR           SAN_PABLO      4.9       8.2       6.2
# 74711   NORTE DE SANTANDER             CACHIRA      7.8       8.3       7.3
# 74712   NORTE DE SANTANDER             CACHIRA      7.8       8.3       7.3
# 74713               TOLIMA        RONCESVALLES      3.9       6.5      10.4
# 74714               TOLIMA        RONCESVALLES      3.9       6.5      10.4
# 74715            SANTANDER            ZAPATOCA      5.5      13.9      18.2
# 74716            SANTANDER            ZAPATOCA      5.5      13.9      18.2
# 74717            SANTANDER          LOS_SANTOS      3.7       8.6       9.8
# 74718            SANTANDER          LOS_SANTOS      3.7       8.6       9.8
# 74719               BOYACA              CUBARA      5.9      31.7      19.1
# 74720               BOYACA              CUBARA      5.9      31.7      19.1
# 74722            ANTIOQUIA             SEGOVIA      3.8       5.5      11.3
# 74723            ANTIOQUIA             SEGOVIA      3.8       5.5      11.3
# 74724            SANTANDER          LOS_SANTOS      4.0       7.5       8.8
# 74725            SANTANDER          LOS_SANTOS      4.0       7.5       8.8
# 74727              CORDOBA              AYAPEL     15.8       6.6       6.6
# 74728              CORDOBA              AYAPEL     15.8       6.6       6.6
# 74729            SANTANDER          LOS_SANTOS      6.3       9.5      17.3
# 74730            SANTANDER          LOS_SANTOS      6.3       9.5      17.3
# 74731            SANTANDER          LOS_SANTOS      5.0       8.3      11.9
# 74732            SANTANDER          LOS_SANTOS      4.5       8.7      12.9
# 74733            SANTANDER          LOS_SANTOS      4.5       8.7      12.9
# 74734            SANTANDER          LOS_SANTOS      5.0       8.3      11.9
# 74735            SANTANDER          LOS_SANTOS      7.4      14.6      20.7
# 74736            SANTANDER          LOS_SANTOS      7.4      14.6      20.7
# 74737            SANTANDER          LOS_SANTOS      5.2       9.8      15.3
# 74738            SANTANDER          LOS_SANTOS      5.2       9.8      15.3
# 74739      VALLE DEL CAUCA             SEVILLA      8.0      11.0      14.7
# 74740      VALLE DEL CAUCA             SEVILLA      8.0      11.0      14.7
# 74741                 META         SAN_JUANITO      7.0       9.7      11.9
# 74742                 META         SAN_JUANITO      7.0       9.7      11.9
# 74743            ANTIOQUIA  SANTA_FE_ANTIOQUIA      3.0       7.8       7.5
# 74744            ANTIOQUIA  SANTA_FE_ANTIOQUIA      3.0       7.8       7.5
# 74745                CHOCO      MEDIO_SAN_JUAN     12.0      10.3      43.1
# 74746                CHOCO      MEDIO_SAN_JUAN     12.0      10.3      43.1
# 148985     VALLE DEL CAUCA        BUENAVENTURA      1.9       3.5       5.8
# 148986     VALLE DEL CAUCA        BUENAVENTURA      1.9       3.5       5.8
# 150180             QUINDIO              GENOVA      3.9       5.4       6.2
# 150181             QUINDIO              GENOVA      3.9       5.4       6.2
# 150781           SANTANDER          LOS_SANTOS      2.6       3.6       4.6
# 150782           SANTANDER          LOS_SANTOS      2.6       3.6       4.6
# 168884           ANTIOQUIA            EL_BAGRE      3.4       3.7       4.5
# 168885           ANTIOQUIA            EL_BAGRE      3.4       3.7       4.5
#
#           ESTADO
# 55267   Revisado
# 55268   Revisado
# 74701   Revisado
# 74702   Revisado
# 74703   Revisado
# 74704   Revisado
# 74705   Revisado
# 74706   Revisado
# 74707   Revisado
# 74708   Revisado
# 74709   Revisado
# 74710   Revisado
# 74711   Revisado
# 74712   Revisado
# 74713   Revisado
# 74714   Revisado
# 74715   Revisado
# 74716   Revisado
# 74717   Revisado
# 74718   Revisado
# 74719   Revisado
# 74720   Revisado
# 74722   Revisado
# 74723   Revisado
# 74724   Revisado
# 74725   Revisado
# 74727   Revisado
# 74728   Revisado
# 74729   Revisado
# 74730   Revisado
# 74731   Revisado
# 74732   Revisado
# 74733   Revisado
# 74734   Revisado
# 74735   Revisado
# 74736   Revisado
# 74737   Revisado
# 74738   Revisado
# 74739   Revisado
# 74740   Revisado
# 74741   Revisado
# 74742   Revisado
# 74743   Revisado
# 74744   Revisado
# 74745   Revisado
# 74746   Revisado
# 148985  Revisado
# 148986  Revisado
# 150180  Revisado
# 150181  Revisado
# 150781  Revisado
# 150782  Revisado
# 168884  Revisado
# 168885  Revisado

# %%
seismic_1st_batch = seismic_1st_batch.drop_duplicates()
seismic_1st_batch[seismic_1st_batch.duplicated(subset=seismic_1st_batch.columns, keep=False)]
# Out:
# Empty DataFrame
# Columns: [FECHA, HORA_UTC, LAT, LONG, PROF., MAGNITUD Ml, MAGNITUD Mw, DEPARTAMENTO, MUNICIPIO, ERR-LAT, ERR-LONG, ERR-PROF, ESTADO]
# Index: []

# %%
seismic_2nd_batch[seismic_2nd_batch.duplicated(subset=seismic_2nd_batch.columns, keep=False)]
# Out:
# Empty DataFrame
# Columns: [FECHA - HORA UTC, LAT, LONG, PROF., MAGNITUD, TIPO MAGNITUD, ERR-LAT, ERR-LONG, ERR-PROF, REGION, ESTADO]
# Index: []

# %% [markdown]
# ### Checking for NaN

# %%
print("NaN:\n")
print(seismic_1st_batch.isna().sum())
print("\n Missing cells\n", seismic_1st_batch.isna().sum().sum())
# Out:
# NaN:
#
# FECHA                0
# HORA_UTC             0
# LAT                  0
# LONG                 0
# PROF.                0
# MAGNITUD Ml          0
# MAGNITUD Mw     168704
# DEPARTAMENTO         0
# MUNICIPIO            0
# ERR-LAT            189
# ERR-LONG           189
# ERR-PROF           189
# ESTADO               0
# dtype: int64
#
#  Missing cells
#  169271

# %%
print("NaN:\n")
print(seismic_2nd_batch.isna().sum())
print("\n Missing cells\n", seismic_2nd_batch.isna().sum().sum())
# Out:
# NaN:
#
# FECHA - HORA UTC    0
# LAT                 0
# LONG                0
# PROF.               0
# MAGNITUD            0
# TIPO MAGNITUD       0
# ERR-LAT             0
# ERR-LONG            0
# ERR-PROF            0
# REGION              0
# ESTADO              0
# dtype: int64
#
#  Missing cells
#  0

# %% [markdown]
# ### Zoom in on missing values

# %%
tmp = np.where(seismic_1st_batch['MAGNITUD Mw'].notnull())
print("Number of NaN:", tmp[0].size)

for i in range(5): #len(tmp[0])):
    index = tmp[0][i]
    #print(seismic_1st_batch[['MAGNITUD Ml', 'MAGNITUD Mw']].iloc[index])
    if seismic_1st_batch['MAGNITUD Ml'].iloc[index] == np.nan:
        print("Index with empty value for MAGNITUD Ml")
# Out:
# Number of NaN: 4544

# %% [markdown]
# As we can see, there are just four values for Mw with the respectiv Ml, so may no sense to keep the Mw magnitued column

# %%
seismic_1st_batch.drop(columns='MAGNITUD Mw', inplace=True)
seismic_1st_batch.rename(columns={'MAGNITUD Ml': 'MAGNITUD'}, inplace=True)
print("NaN:\n")
print(seismic_1st_batch.isna().sum())
# Out:
# NaN:
#
# FECHA             0
# HORA_UTC          0
# LAT               0
# LONG              0
# PROF.             0
# MAGNITUD          0
# DEPARTAMENTO      0
# MUNICIPIO         0
# ERR-LAT         189
# ERR-LONG        189
# ERR-PROF        189
# ESTADO            0
# dtype: int64

# %% [markdown]
# Regardin the missing values for Latitude, longitude, and deep errors, lets replace them with the respective average

# %%
aveErrLat = seismic_1st_batch['ERR-LAT'].mean()
aveErrLon = seismic_1st_batch['ERR-LONG'].mean()
aveErrPro = seismic_1st_batch['ERR-PROF'].mean()
#
seismic_1st_batch['ERR-LAT'].fillna(aveErrLat, inplace=True)
seismic_1st_batch['ERR-LONG'].fillna(aveErrLon, inplace=True)
seismic_1st_batch['ERR-PROF'].fillna(aveErrPro, inplace=True)
#
print("NaN:\n")
print(seismic_1st_batch.isna().sum())
# Out:
# NaN:
#
# FECHA           0
# HORA_UTC        0
# LAT             0
# LONG            0
# PROF.           0
# MAGNITUD        0
# DEPARTAMENTO    0
# MUNICIPIO       0
# ERR-LAT         0
# ERR-LONG        0
# ERR-PROF        0
# ESTADO          0
# dtype: int64

# %%
# Merging columns FECHA and HORA_UTC
seismic_1st_batch['FECHA - HORA UTC'] = seismic_1st_batch['FECHA'] + ' ' + seismic_1st_batch['HORA_UTC']
seismic_1st_batch.drop(columns=['FECHA', 'HORA_UTC'], inplace=True)

for i in seismic_1st_batch.columns.to_list():
    print(i)
# Out:
# LAT
# LONG
# PROF.
# MAGNITUD
# DEPARTAMENTO
# MUNICIPIO
# ERR-LAT
# ERR-LONG
# ERR-PROF
# ESTADO
# FECHA - HORA UTC

# %% [markdown]
# ### Checking for magnitudes in the second batch

# %%
for i in seismic_2nd_batch['TIPO MAGNITUD'].value_counts().index:
    print(i)
# Out:
# MLr_3
# MLr_2
# MLr_1
# MLr_vmm
# MLr_4
# MLr
# M_MLr
# MLr_5
# M
# Mw(mB)
# Mw
# mb
# Mwp
# MLv
# Mw(Mwp)
# ML
# mB

# %% [markdown]
# As an approach, for this analysis we are considering all the magnitudes as Ml, __even though they are not__.
# So, lets drop the column 'TIPO DE MAGNITUD'

# %%
seismic_2nd_batch.drop(columns='TIPO MAGNITUD', inplace=True)
seismic_2nd_batch.columns.to_list()
# Out:
# ['FECHA - HORA UTC',
#  'LAT',
#  'LONG',
#  'PROF.',
#  'MAGNITUD',
#  'ERR-LAT',
#  'ERR-LONG',
#  'ERR-PROF',
#  'REGION',
#  'ESTADO']

# %% [markdown]
# Lest zoom in on MUNICIPO and DEPARTAMENTE, first batch, and for REGION, second batch

# %%
print(seismic_1st_batch[['MUNICIPIO', 'DEPARTAMENTO']].iloc[1])
print("\n")
print(seismic_2nd_batch['REGION'].iloc[1])
# Out:
# MUNICIPIO       LOS_SANTOS
# DEPARTAMENTO     SANTANDER
# Name: 1, dtype: object
#
#
# Tame - Arauca, Colombia

# %% [markdown]
# In this case, "REGION: Los Santons - Santander, Colombia" means:
# - MUNICIPIO = Tame
# - DEPARTAMENTO = Arauca
#
# So, lets put into the column REGION just the MUNICIPIO, create a new column DEPARTAMENTO by putting the respective value, and rename REGION as MUNICIPIO

# %%
tmp_a = seismic_2nd_batch['REGION'].str.split('-').str[0].str.strip()
tmp_b = seismic_2nd_batch['REGION'].str.split(',').str[0].str.strip()
tmp_c = tmp_b.str.split('-').str[1].str.strip()
#
seismic_2nd_batch['REGION'] = tmp_a
seismic_2nd_batch['DEPARTAMENTO'] = tmp_c

seismic_2nd_batch.rename(columns={'REGION': 'MUNICIPIO'}, inplace=True)
seismic_2nd_batch[['MUNICIPIO', 'DEPARTAMENTO']].iloc[1]
# Out:
# MUNICIPIO         Tame
# DEPARTAMENTO    Arauca
# Name: 1, dtype: object

# %% [markdown]
# ### Checking if missing values

# %%
seismic_2nd_batch.isna().sum()
# Out:
# FECHA - HORA UTC       0
# LAT                    0
# LONG                   0
# PROF.                  0
# MAGNITUD               0
# ERR-LAT                0
# ERR-LONG               0
# ERR-PROF               0
# MUNICIPIO              0
# ESTADO                 0
# DEPARTAMENTO        6520
# dtype: int64

# %%
tmp_df = seismic_2nd_batch[seismic_2nd_batch['DEPARTAMENTO'].isna()]
tmp_df['MUNICIPIO'].value_counts()
# Out:
# Océano Pacífico                               2925
# Mar Caribe                                    1302
# Venezuela                                      799
# Area de Influencia Volcán Nevado del Huila     449
# Norte Colombia                                 174
# Caribbean Sea                                  173
# Panama                                         143
# Cerca de la Costa de Colombia                  137
# Área de Influencia Volcán Nevado del Huila      91
# Cerca de la Costa de Venezuela                  66
# Sur de Panama                                   55
# Northern Colombia                               29
# Volcán Chiles                                   28
# Cerca de la Costa de Ecuador                    26
# Cerca de la Costa Oeste de Colombia             25
# Near North Coast of Colombia                    21
# Near Coast of Venezuela                         15
# Colombia                                         9
# Área de Influencia Volcán Chiles                 7
# Volcán Galeras                                   6
# Near West Coast of Colombia                      5
# Costa Rica                                       4
# Norte de Panama                                  4
# Ecuador                                          2
# North of Panama                                  2
# Lago Maracaibo, Venezuela                        2
# Central America                                  1
# South of Panama                                  1
# Volcan Galeras                                   1
# Volcán Nevado del Ruiz                           1
# Volcán Cerro Negro                               1
# Masachapa, Nicaragua                             1
# Quesada, Guatemala                               1
# Lake Maracaibo, Venezuela                        1
# Costa Afuera de Centro America                   1
# Off Coast of Central America                     1
# Nicaragua                                        1
# Puerto El Triunfo, El Salvador                   1
# Norte de Peru                                    1
# La Cruz, Costa Rica                              1
# Área de Influencia Volcán Cerro Negro            1
# Área de Influencia Volcán Azufral                1
# Brasil Occidental                                1
# Limones, Panama                                  1
# off the coast of Central America                 1
# off the coast of Central America.                1
# Volcán Las Animas                                1
# Name: MUNICIPIO, dtype: int64

# %% [markdown]
# As we can see, all this seismics were located outside, or close by, the Colombia's border, so lets to drop them

# %%
tmp_index = seismic_2nd_batch[seismic_2nd_batch.isna().any(axis=1)].index
seismic_2nd_batch = seismic_2nd_batch.drop(tmp_index)

seismic_2nd_batch.isna().sum()
# Out:
# FECHA - HORA UTC    0
# LAT                 0
# LONG                0
# PROF.               0
# MAGNITUD            0
# ERR-LAT             0
# ERR-LONG            0
# ERR-PROF            0
# MUNICIPIO           0
# ESTADO              0
# DEPARTAMENTO        0
# dtype: int64

# %%
for i in seismic_1st_batch.columns.to_list():
    print(i)
print(seismic_1st_batch.shape)
print("\n")
for i in seismic_2nd_batch.columns.to_list():
    print(i)
print(seismic_2nd_batch.shape)
# Out:
# LAT
# LONG
# PROF.
# MAGNITUD
# DEPARTAMENTO
# MUNICIPIO
# ERR-LAT
# ERR-LONG
# ERR-PROF
# ESTADO
# FECHA - HORA UTC
# (173248, 11)
#
#
# FECHA - HORA UTC
# LAT
# LONG
# PROF.
# MAGNITUD
# ERR-LAT
# ERR-LONG
# ERR-PROF
# MUNICIPIO
# ESTADO
# DEPARTAMENTO
# (119939, 11)

# %%
seismic_merged = pd.concat([seismic_1st_batch, seismic_2nd_batch])
seismic_merged = seismic_merged.reset_index(drop=True)

# %%
for i in seismic_merged.columns.to_list():
    print(i)
print(seismic_merged.shape)
# Out:
# LAT
# LONG
# PROF.
# MAGNITUD
# DEPARTAMENTO
# MUNICIPIO
# ERR-LAT
# ERR-LONG
# ERR-PROF
# ESTADO
# FECHA - HORA UTC
# (293187, 11)

# %%
print("NaN:\n")
print(seismic_merged.isna().sum(), '\n')
# Out:
# NaN:
#
# LAT                 0
# LONG                0
# PROF.               0
# MAGNITUD            0
# DEPARTAMENTO        0
# MUNICIPIO           0
# ERR-LAT             0
# ERR-LONG            0
# ERR-PROF            0
# ESTADO              0
# FECHA - HORA UTC    0
# dtype: int64

# %%
profile = ProfileReport(seismic_merged, title="Seismic from 1st Jan. 1993 to 31st May 2023")
profile.to_file("report_1st_jan_93_to_31st_may_23.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# Generate report structure:   0%|          | 0/1 [00:00<?, ?it/s]
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ## Saving the Dataframe into a CSV and XLSX file

# %%
seismic_merged.to_csv('data/seismic_1st_jan_93_to_31st_may_23.csv', index=False)
seismic_merged.to_excel('data/seismic_1st_jan_93_to_31st_may_23.xlsx', index=False)
